# %%
# Importing the pandas library
import pandas as pd

# %%
# Loading our first data set, CDR_Description
df1 = pd.read_excel (r"/content/CDR_description.xlsx")
df1.head(5)
# Out:
#        Column name                                        Description   Format
# 0          PRODUCT                                       Voice or SMS   String
# 1            VALUE                                      Billing price  Integer
# 2        DATE_TIME               Time in format yyyy-MM-dd hh:mm:ss.0   String
# 3     CELL_ON_SITE  Which cell in the site was used (not needed here)  Integer
# 4  DW_A_NUMBER_INT  Anonymized phone number of the person for whic...   String

# %%
# Loading our second data set, Cell_geo while delimitting the semicolon
df2 = pd.read_csv(r'/content/cells_geo.csv',delimiter = ';')
df2.head(10)
df2.columns = ["VALUE",'CITY' ,'STATUS' ,'LOCALISATION ','GEO_ZONE' ,'ZONE_NAME' ,"LONGITUDE", "LATITUDE", "REGION","AREA", "CELL_ID", "SITE_CODE"]
df2
# Number of cities in Ivory coast
list(df2['CITY'].unique())
# Out:
# ['ADJAME',
#  'ASSINIE',
#  'KRIKOREA',
#  'ABOBO',
#  'BINGERVILLE',
#  'PLATEAU',
#  'DALOA',
#  'ABENGOUROU',
#  'ATTECOUBE',
#  'ABOISSO COMOE',
#  'ABOISSO',
#  'BONGOUANOU',
#  'ABONGOUA',
#  'ABOUDEKOUASSIKRO',
#  'ABRONAMOUE',
#  'YOPOUGON',
#  'ADAOU',
#  'ADDAH',
#  'ADEBEM',
#  'ADIAKE',
#  'ADJAMENE',
#  'PORT-BOUET',
#  'ADZOPE',
#  'AFFERY',
#  'COCODY',
#  'AGBOVILLE',
#  'AGNIBILEKRO',
#  'AGONDA',
#  'AGOU',
#  'MARCORY',
#  'AHIZABRO',
#  'AHOUANOU',
#  'BOUAKE',
#  'AKOBOISSUE',
#  'AKOUPE',
#  'AKOUYAKRO',
#  'AKRADJO',
#  'KOUMASSI',
#  'ALEPE',
#  'ALERIA',
#  'BAMORO',
#  'ALLOKOI',
#  'ANANDA',
#  'ANDO',
#  'ANDOKOKRENOU',
#  'ANIANSUE',
#  'ANOUMABA',
#  'ANYAMA',
#  'AOUNIANFOUTOU',
#  'APPOISSO',
#  'ARRAH',
#  'ASSIKOI',
#  'ASSUEFRY',
#  'ATTIGUEHI',
#  'ATTINGUIE',
#  'ATTROBROU',
#  'AYAME',
#  'AYAPRIKRO',
#  'AZAGUIE',
#  'BACANDA',
#  'BADIKAHA',
#  'BAGOHOUO',
#  'BAHOMPA',
#  'BACOUBLY',
#  'BALEKO',
#  'SAN-PEDRO',
#  'BANADJE',
#  'BANANKORO',
# ...

# %%
# Loading our third data set, cells_geo_description
df3 = pd.read_excel (r"/content/cells_geo_description.xlsx")
df3
# Out:
#      Column name                                        Description  Format
# 0         VILLES                                               City  String
# 1         STATUS                                  In Service or not  String
# 2   LOCALISATION                                  in ABIDJAN or not  String
# 3     DECOUPZONE                                  Geographical Zone  String
# 4       ZONENAME                                       Name of Zone  String
# 5      LONGITUDE                                          Longitude   Float
# 6       LATITUDE                                           Latitude   Float
# 7         REGION                                             Region  String
# 8           AREA                                               Area  String
# 9        CELL_ID                                     ID of the cell  String
# 10     SITE_CODE  Site (there are several cells per site, severa...  String

# %%
display(df1,df2)
# Out:
#        Column name                                        Description   Format
# 0          PRODUCT                                       Voice or SMS   String
# 1            VALUE                                      Billing price  Integer
# 2        DATE_TIME               Time in format yyyy-MM-dd hh:mm:ss.0   String
# 3     CELL_ON_SITE  Which cell in the site was used (not needed here)  Integer
# 4  DW_A_NUMBER_INT  Anonymized phone number of the person for whic...   String
# 5  DW_B_NUMBER_INT        Anonymized phone number of the counterparty   String
# 6        COUNTRY_A                  Country of party A (useless here)   String
# 7        COUNTRY_B                  Country of party B (useless here)   String
# 8          CELL_ID                                     ID of the cell   String
# 9          SITE_ID                                     ID of the SITE   String
#       VALUE      CITY      STATUS  ...          AREA     CELL_ID   SITE_CODE
# ...

# %%
# Loading telecom dataset one
df4 = pd.read_csv('/content/Telcom_dataset.csv')
df4
# Changing column productc to product
df4.columns = ['PRODUCT' ,'VALUE' ,'DATETIME ',' CELL_ON _SITE ' ,'DW_A_NUMBER_INT ' ,' DW_B_NUMBER_INT', "COUNTRY_A", "COUNTRY_B", "CELL_ID", "SITE_CODE"]
df4
# Dropping null values
df4.dropna(how  = "all" )
df4
# Finding the most used data on day two
df_ = pd.value_counts(df4['PRODUCT'])
df_.head(3)

df4["VALUE"]. sum()
# Out:
# 129374

# %%
# Loading telecom dataset two
df5 = pd.read_csv('/content/Telcom_dataset2.csv')
df5
# changing columns for telcom dataset
df5.columns = ['PRODUCT' ,'VALUE' ,'DATETIME ',' CELL_ON _SITE ' ,'DW_A_NUMBER_INT ' ,' DW_B_NUMBER_INT', "COUNTRY_A", "COUNTRY_B", "CELL_ID", "SITE_CODE"]
df5.head(5)
df5.dropna(how  = "all" )
df5
# Finding the most used data on day two
df_ = pd.value_counts(df5['PRODUCT'])
df_.head(3)
# Out:
# sms      2329
# Voice    1906
# data      766
# Name: PRODUCT, dtype: int64

# %%
# Loading telecom dataset three
df6 = pd.read_csv('/content/Telcom_dataset3.csv')
df6
df6.columns = ['PRODUCT' ,'VALUE' ,'DATETIME ',' CELL_ON _SITE ' ,'DW_A_NUMBER_INT ' ,' DW_B_NUMBER_INT', "COUNTRY_A", "COUNTRY_B", "CELL_ID", "SITE_CODE"]
df6.head(5)
# Removing null values
df6.dropna(how  = "all" )
df6
# Finding the most used produt on day three
df_ = pd.value_counts(df6['PRODUCT'])
df_.head(3)
# Out:
# sms      2767
# Voice    1541
# data      693
# Name: PRODUCT, dtype: int64

# %%
# Merging the telcom datasets
df_all = pd.concat((df4, df5, df6), axis=0, ignore_index=True)
df_all.head(10)

# merging the telecom dataset with cells_geo
df_merge1 = pd.merge(df_all, df2, on='SITE_CODE', how = 'left')
df_merge1
df = df_merge1
df
# Finding the most used product in the three days
df_product = pd.value_counts(df['PRODUCT'])
df_product.head(3)
# Finding the top 10 cities with the highest frequency of calls and sms
df1_ = pd.value_counts(df['CITY'])
df1_.head(30)
# Finding the most used product in MTN
df['PRODUCT'].max()
# Finding the region with the highest frequency
df_2= pd.value_counts(df['REGION'])
df_2.head(3)
# Out:
# LAGUNE           33684
# LACS              2484
# BAS SASSANDRA     2395
# Name: REGION, dtype: int64

# %%
#  Spliting date and time
df["DATE"] = df['DATETIME'].apply(lambda x: pd.Series([i for i in reversed(x.lower().split(" "))]))
# df[['DATE','TIME']] = df.DATETIME.str.split(" ",expand=True,)
df
df.drop(["DATE"], axis = 1)
df["DATE"] = df["DATETIME"].str.split(" ", n=1, expand = True)
df
# drop the datetime column
# df_3 = df.drop(columns=["DATETIME"])
# df_3
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DATETIME'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-115-278e62d73ae0> in <module>()
# ...
